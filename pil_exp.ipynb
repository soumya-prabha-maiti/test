# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Load the image using PIL
image = Image.open('data/train/train_85.bmp').convert("L")

# Convert the image to a numpy array
image_array = np.array(image)
print(image_array.shape)

# Display the image using matplotlib
plt.imshow(image_array)
plt.axis('off')
plt.show()
# Out:
# (522, 775)

# %%
print(np.expand_dims(image_array, axis=-1).shape)
# Out:
# (522, 775, 1)

# %%
image_array.shape
# Out:
# (522, 775, 3)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Load the image using cv2
image = cv2.imread('data/train/train_85.bmp')
print(image.shape)

# Display the image using matplotlib
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Load the image using cv2
image = cv2.imread('data/train/train_85.bmp')
print(image.shape)

# Display the image using matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))
plt.axis('off')
plt.show()
